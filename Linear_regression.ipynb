# %% [markdown]
# ###LINEAR REGRESSION

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import numpy as np
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')
df = pd.get_dummies(df,columns=['species'],drop_first=True,dtype='int')
x = df.drop(['sepal_length'],axis=1)
y = df['sepal_length']
#feature engineering
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
#training the data
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=42)

model = LinearRegression()
model.fit(x_train,y_train)
pred_value = model.predict(x_test)
#metrics
print("mse",mean_squared_error(y_test,pred_value))
print("mae",mean_absolute_error(y_test,pred_value))
print("mse",np.sqrt(mean_squared_error(y_test,pred_value)))
print("r2_score",(r2_score(y_test,pred_value))*100)
#visualation
plt.figure(figsize=(10, 6))
plt.scatter(y_test, pred_value, color='blue', label='Predictions vs Actual')
plt.plot([y_test.min(), y_test.max()], [y_test.min(), y_test.max()], color='red', linestyle='solid', label='Perfect Fit Line')
plt.xlabel('Actual Sepal Length')
plt.ylabel('Predicted Sepal Length')
plt.title('Actual vs Predicted Sepal Length')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# mse 0.09211496169144945
# mae 0.22765791555049036
# mse 0.3035044673335954
# r2_score 86.65516297690031

# %% [markdown]
# ###MULTIPLE LINEAR REGRESSION

# %%
import seaborn as sns
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split,cross_val_score
from sklearn.linear_model import LinearRegression,Lasso,Ridge
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score
import numpy as np
import matplotlib.pyplot as plt

df = sns.load_dataset('iris')
df = pd.get_dummies(df,columns=['species'],drop_first=True,dtype='int')
x = df.drop(['sepal_length','petal_length','petal_width'],axis=1)
y = df['sepal_length']
#feature engineering
scaler = StandardScaler()
x_scaled = scaler.fit_transform(x)
#training the data
x_train,x_test,y_train,y_test = train_test_split(x_scaled,y,test_size=0.2,random_state=42)

model = LinearRegression()
model.fit(x_train,y_train)
pred_value = model.predict(x_test)
#metrics
print("mse",mean_squared_error(y_test,pred_value))
print("mae",mean_absolute_error(y_test,pred_value))
print("mse",np.sqrt(mean_squared_error(y_test,pred_value)))
print("r2_score",(r2_score(y_test,pred_value))*100)
#visualization
plt.scatter(y_test,pred_value,color='red',label='actual vs predicted value')
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()],color = 'blue', label='line')
plt.legend
plt.xlabel('actual_value')
plt.ylabel('predicted_value')
plt.title('multi linear regression')
plt.grid(True)
plt.show()
# Out:
# mse 0.18971437204929303
# mae 0.30060936054878523
# mse 0.43556213339693917
# r2_score 72.5157853898069
